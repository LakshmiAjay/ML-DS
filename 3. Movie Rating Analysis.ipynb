# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
movies = pd.read_csv("/content/drive/MyDrive/Machine learning/movies.dat", delimiter='::')
print(movies.head())
# Out:
#    0000008      Edison Kinetoscopic Record of a Sneeze (1894)  \
# 0       10                La sortie des usines Lumière (1895)
# 1       12                      The Arrival of a Train (1896)
# 2       25  The Oxford and Cambridge University Boat Race ...
# 3       91                         Le manoir du diable (1896)
# 4      131                           Une nuit terrible (1896)
#
#      Documentary|Short
# 0    Documentary|Short
# 1    Documentary|Short
# 2                  NaN
# 3         Short|Horror
# 4  Short|Comedy|Horror
# <ipython-input-19-bcb5b0ce28ac>:1: ParserWarning:
#
# Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
movies.columns = ["ID", "Title", "Genre"]
print(movies.head())
# Out:
#     ID                                              Title                Genre
# 0   10                La sortie des usines Lumière (1895)    Documentary|Short
# 1   12                      The Arrival of a Train (1896)    Documentary|Short
# 2   25  The Oxford and Cambridge University Boat Race ...                  NaN
# 3   91                         Le manoir du diable (1896)         Short|Horror
# 4  131                           Une nuit terrible (1896)  Short|Comedy|Horror

# %%
ratings = pd.read_csv("/content/drive/MyDrive/Machine learning/ratings.dat", delimiter='::')
print(ratings.head())
# Out:
# <ipython-input-21-97ca4964b366>:1: ParserWarning:
#
# Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#    1  0114508  8  1381006850
# 0  2   499549  9  1376753198
# 1  2  1305591  8  1376742507
# 2  2  1428538  1  1371307089
# 3  3    75314  1  1595468524
# 4  3   102926  9  1590148016

# %%
ratings.columns = ["User", "ID", "Ratings", "Timestamp"]
print(ratings.head())
# Out:
#    User       ID  Ratings   Timestamp
# 0     2   499549        9  1376753198
# 1     2  1305591        8  1376742507
# 2     2  1428538        1  1371307089
# 3     3    75314        1  1595468524
# 4     3   102926        9  1590148016

# %%
data = pd.merge(movies, ratings, on=["ID", "ID"])
print(data.head())
# Out:
#    ID                                              Title              Genre  \
# 0  10                La sortie des usines Lumière (1895)  Documentary|Short
# 1  12                      The Arrival of a Train (1896)  Documentary|Short
# 2  25  The Oxford and Cambridge University Boat Race ...                NaN
# 3  91                         Le manoir du diable (1896)       Short|Horror
# 4  91                         Le manoir du diable (1896)       Short|Horror
#
#     User  Ratings   Timestamp
# 0  70577       10  1412878553
# 1  69535       10  1439248579
# 2  37628        8  1488189899
# 3   5814        6  1385233195
# 4  37239        5  1532347349

# %%
ratings = data["Ratings"].value_counts()
numbers = ratings.index
quantity = ratings.values
fig = px.pie(data, values=quantity, names=numbers)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(data["Title"].value_counts().head(10))
# Out:
# Gravity (2013)                    3104
# Interstellar (2014)               2948
# 1917 (2019)                       2879
# The Wolf of Wall Street (2013)    2836
# Joker (2019)                      2753
# Man of Steel (2013)               2694
# World War Z (2013)                2429
# Iron Man Three (2013)             2417
# Now You See Me (2013)             2379
# Gone Girl (2014)                  2284
# Name: Title, dtype: int64

# %%
ratings = data["Ratings"].value_counts()
type(ratings)
# Out:
# pandas.core.series.Series

# %%
movies
# Out:
#              ID                                              Title  \
# 0            10                La sortie des usines Lumière (1895)
# 1            12                      The Arrival of a Train (1896)
# 2            25  The Oxford and Cambridge University Boat Race ...
# 3            91                         Le manoir du diable (1896)
# 4           131                           Une nuit terrible (1896)
# ...         ...                                                ...
# 37336  14499632                                22 vs. Earth (2021)
# 37337  14527836                                    Recalled (2021)
# 37338  14544192                          Bo Burnham: Inside (2021)
# 37339  14735160                             Mum is Pregnant (2021)
# 37340  14740904                              Juanes: Origen (2021)
#
#                            Genre
# 0              Documentary|Short
# 1              Documentary|Short
# 2                            NaN
# ...

# %%
data
# Out:
#               ID                                              Title  \
# 0             10                La sortie des usines Lumière (1895)
# 1             12                      The Arrival of a Train (1896)
# 2             25  The Oxford and Cambridge University Boat Race ...
# 3             91                         Le manoir du diable (1896)
# 4             91                         Le manoir du diable (1896)
# ...          ...                                                ...
# 908627  14544192                          Bo Burnham: Inside (2021)
# 908628  14544192                          Bo Burnham: Inside (2021)
# 908629  14544192                          Bo Burnham: Inside (2021)
# 908630  14735160                             Mum is Pregnant (2021)
# 908631  14740904                              Juanes: Origen (2021)
#
#                      Genre   User  Ratings   Timestamp
# 0        Documentary|Short  70577       10  1412878553
# ...

# %%
data1=data.copy()

# %%
a=data1['Title'].str.split('(', n = 1)

# %%
# a=a.str.split(')', n = 1)

# %%
a=a.tolist()

# %%
data['Title'].value_counts()
# Out:
# Gravity (2013)                    3104
# Interstellar (2014)               2948
# 1917 (2019)                       2879
# The Wolf of Wall Street (2013)    2836
# Joker (2019)                      2753
#                                   ...
# Bennys gym (2007)                    1
# Pretty Bird (2008)                   1
# American Swing (2008)                1
# Suay Laak Sai (2007)                 1
# Juanes: Origen (2021)                1
# Name: Title, Length: 37269, dtype: int64

# %%
a=pd.DataFrame(a)

# %%
a=a[1].str.split(')', n = 1)

# %%
data1['Year']=pd.DataFrame(a.tolist())[0]

# %%
a=data1.Title.drop_duplicates().tolist()

# %%
len(a)
# Out:
# 37269

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 908632 entries, 0 to 908631
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ID         908632 non-null  int64
#  1   Title      908632 non-null  object
#  2   Genre      908272 non-null  object
#  3   User       908632 non-null  int64
#  4   Ratings    908632 non-null  int64
#  5   Timestamp  908632 non-null  int64
#  6   Year       908632 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 87.7+ MB

# %%
data1['Year'] = data1['Year'].astype(int)

# %%
# for i in data1.Title.unique():
#    w=data1[data1['Title']==i]['Genre'].count()
#    L=data1[data1['Title']==i]['Genre'].tolist()
#    l= ' '.join([str(elem) for elem in L])
#    print(f'number of Genre of movie{i} is {w} and those are {l}' )
